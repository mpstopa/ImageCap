# %%
from configs.default import _C as config # this means configs/default.py and _C is inside that python file
from configs.default import update_config # likewise the function update_config

from datasets import flickr8k_parse

from keras import backend as K
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.optimizers import RMSprop
from keras.backend.tensorflow_backend import set_session
from models import batch_generator, decoder
from keras.utils.vis_utils import plot_model

import json
import numpy as np
import os
import pandas as pd
import path_generation
import tensorflow as tf
import text_processing
import time
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9629155014729828496]

# %%
config_file = "./configs/attn.yaml"
update_config(config, config_file) # config is imported from default.py _C above
# most parameters are in default.py, parameters in attn.yaml overwrite these defaults

# %% [markdown]
# # Decoder

# %% [markdown]
# ### Captions encoding

# %% [markdown]
# Before building decoder, it is necessary to encode captions into one-hot vectors which further would be used in embedding layer.

# %% [markdown]
# ### COCO dataset

# %%
if config.DATASET == 'Coco':
    if config.ATTENTION:
        features_file_train = "vgg16_coco_train_attn.npy"
        features_file_val = "vgg16_coco_val_attn.npy"
    else:
        features_file_train = "vgg16_coco_train.npy"
        features_file_val = "vgg16_coco_val.npy"
    
    
    val_filenames_with_captions = coco_parse.get_image_filename_with_caption(config.PATH.ANNOTATIONS_PATH, 
                                                                             config.PATH.IMG_PATH, 
                                                                             train=False)

    val_filenames_with_all_captions = coco_parse.get_image_with_all_captions(val_filenames_with_captions)

    train_filenames_with_captions = coco_parse.get_image_filename_with_caption(config.PATH.ANNOTATIONS_PATH, 
                                                                               config.PATH.IMG_PATH,
                                                                               train=True)
    train_filenames_with_all_captions = coco_parse.get_image_with_all_captions(train_filenames_with_captions)

    ### Extract captions
    train_captions = coco_parse.make_list_of_captions(train_filenames_with_all_captions)
    val_captions = coco_parse.make_list_of_captions(val_filenames_with_all_captions)

# %% [markdown]
# ### Flickr8k dataset

# %%
if config.DATASET == 'Flickr8k':
    if config.ATTENTION:
        features_file_train = "vgg16_flickr8k_train_attn.npy"
        features_file_val = "vgg16_flickr8k_val_attn.npy"
    else:
        features_file_train = "vgg16_flickr8k_train.npy"
        features_file_val = "vgg16_flickr8k_val.npy"

    captions_file = os.path.join(config.PATH.ANNOTATIONS_PATH, "Flickr8k.token.txt")
    train_txt_path = os.path.join(config.PATH.ANNOTATIONS_PATH, "Flickr_8k.trainImages.txt")
    dev_txt_path = os.path.join(config.PATH.ANNOTATIONS_PATH, "Flickr_8k.devImages.txt")
    test_txt_path = os.path.join(config.PATH.ANNOTATIONS_PATH, "Flickr_8k.testImages.txt")    
        
    filenames_with_all_captions = flickr8k_parse.generate_filenames_with_all_captions(captions_file, 
                                                                                      config.PATH.IMG_PATH)
    train_filenames_with_all_captions = flickr8k_parse.generate_set(train_txt_path, 
                                                                    filenames_with_all_captions,
                                                                    config.PATH.IMG_PATH)
    val_filenames_with_all_captions = flickr8k_parse.generate_set(dev_txt_path, 
                                                                  filenames_with_all_captions, 
                                                                  config.PATH.IMG_PATH)
    test_filenames_with_all_captions = flickr8k_parse.generate_set(test_txt_path, 
                                                                   filenames_with_all_captions, 
                                                                   config.PATH.IMG_PATH)

# train_captions, val_captions are just the captions. "_filenames_with_all_captions have jpg filenames too."
    train_captions = flickr8k_parse.make_list_of_captions(train_filenames_with_all_captions)
    val_captions = flickr8k_parse.make_list_of_captions(val_filenames_with_all_captions)

# %%
print('number of rows in val_captions',len(val_captions),'\n number of captions in each row', \
      len(val_captions[0]),'\n val_captions[0:5]',val_captions[0:5])
# Out:
# number of rows in val_captions 1000
#  number of captions in each row 5
#  val_captions[0:5] [['the boy laying face down on a skateboard is being pushed along the ground by another boy .', 'Two girls play on a skateboard in a courtyard .', 'Two people play on a long skateboard .', 'Two small children in red shirts playing on a skateboard .', 'two young children on a skateboard going across a sidewalk'], ['a boy in a blue top is jumping off some rocks in the woods .', 'A boy jumps off a tan rock .', 'A boy jumps up in a field in the woods .', 'A young boy jumps off a rock in the forest', 'Child in blue and grey shirt jumping off hill in the woods'], ['A lady walking her dog through an obstacle course , while other people are in the background .', 'A small tan and white dog and trainer running an obstacle course', 'A woman is guiding a brown dog around an obstacle course', 'A woman with a hat is leading a small dog through an obstacle course .', 'The woman is leading a dog through an obstacle course .'], ['a big black dog jumps in the air to catch the tennis ball in his mouth .', 'A dog looks at another dog catching a ball in the air', 'A white dog is watching a black dog jump on a lawn next to a pile of large rocks .', 'A white dog watching a black dog in the air .', 'Two dogs playing with a tennis ball in the yard .'], ['two woman climbing rocks around the ocean', 'Two women are climbing over rocks near to the ocean .', 'Two women climb on top of rocks in front of the ocean .', 'Two women in bathing suit on large rocks at the ocean .', 'Two women in bathing suits climb rock piles by the ocean .']]

# %%
### Preprocess captions
text_processing.preprocess_captions(val_captions)
text_processing.preprocess_captions(train_captions)

# %%
### Add markers of captions' starts and ends
text_processing.add_start_and_end_to_captions(train_captions)
text_processing.add_start_and_end_to_captions(val_captions)

# %%
### Create vocabulary from the training captions
train_vocab = text_processing.Vocabulary()
for caption_list in train_captions:
    for caption in caption_list:
        tmp_caption_list = caption.split() # make a python list of all words in caption
        for word in tmp_caption_list:
            train_vocab.add_word(word) # add_word is a method on class Vocabulary

# %%
if not os.path.exists(config.PATH.VOCABULARY_PATH):
    os.mkdir(config.PATH.VOCABULARY_PATH)
train_vocab.save_vocabulary(config.VOCABULARY.WORD_TO_ID, config.VOCABULARY.ID_TO_WORD, config.VOCABULARY.COUNT)

# %%
train_captions_tokens = text_processing.tokenise_captions(train_captions, train_vocab)
val_captions_tokens = text_processing.tokenise_captions(val_captions, train_vocab)

# %%
print('train_captions_tokens[0]',train_captions_tokens[0])
print(train_captions[0])
print('len(train_captions_tokens)',len(train_captions_tokens),len(train_captions_tokens[0]),len(train_captions_tokens[0][0]))
print('len(train_captions)',len(train_captions),len(train_captions[0][0]))
# Out:
# train_captions_tokens[0] [[1, 2, 3, 4, 5, 6, 7, 2, 8, 4, 9, 10, 11, 12], [1, 3, 4, 13, 14, 4, 15, 11, 12], [1, 16, 17, 18, 19, 20, 21, 10, 22, 23, 12], [1, 16, 17, 24, 25, 9, 10, 11, 12], [1, 16, 17, 6, 15, 2, 26, 27, 28, 29, 30, 12]]
# ['<sos> a black dog is running after a white dog in the snow <eos>', '<sos> black dog chasing brown dog through snow <eos>', '<sos> two dogs chase each other across the snowy ground <eos>', '<sos> two dogs play together in the snow <eos>', '<sos> two dogs running through a low lying body of water <eos>']
# len(train_captions_tokens) 6000 5 14
# len(train_captions) 6000 64

# %%
train_captions_tokens[0]
# train_captions[0]
# Out:
# [[1, 2, 3, 4, 5, 6, 7, 2, 8, 4, 9, 10, 11, 12],
#  [1, 3, 4, 13, 14, 4, 15, 11, 12],
#  [1, 16, 17, 18, 19, 20, 21, 10, 22, 23, 12],
#  [1, 16, 17, 24, 25, 9, 10, 11, 12],
#  [1, 16, 17, 6, 15, 2, 26, 27, 28, 29, 30, 12]]

# %% [markdown]
# ### Decoder NN

# %% [markdown]
# ### GRU

# %%
path_gen = path_generation.PathGenerator(config.DECODER.GRU, # note that _C in default.py has been imported as config.
                                         config.DATASET, 
                                         config.DECODER.NUM_RNN_LAYERS, 
                                         config.DECODER.BATCH_SIZE, 
                                         config.DECODER.BATCH_NORM, 
                                         config.DECODER.DROPOUT, 
                                         config.ATTENTION, 
                                         config.DECODER.ATTN_TYPE)

path_checkpoint = path_gen.get_weights_path()
model_path = path_gen.get_model_path()
callbacks_path = path_gen.get_callbacks_path()

# %%
features_file_train_path = os.path.join(config.PATH.FEATURES_PATH, features_file_train)
features_file_val_path = os.path.join(config.PATH.FEATURES_PATH, features_file_val)

transfer_values = np.load(features_file_train_path) # loads from .npy or .npz file
print('transfer_values.shape',transfer_values.shape)
print('transfer_values[121,0:45]',transfer_values[121,0:45])
val_transfer_values = np.load(features_file_val_path)
print('val_transfer_values.shape',val_transfer_values.shape)
# Out:
# transfer_values.shape (6000, 14, 14, 512)
# transfer_values[121,0:45] [[[0.05983141 0.         0.         ... 0.         0.7467803  0.        ]
#   [0.10442781 0.         0.         ... 0.         0.58881134 0.        ]
#   [0.00977734 0.         0.         ... 0.         0.681288   0.        ]
#   ...
#   [0.         0.         0.         ... 0.         0.71781266 0.        ]
#   [0.04952595 0.         0.         ... 0.         0.79048127 0.        ]
#   [0.13595301 0.         0.         ... 0.         0.7541306  0.        ]]
#
#  [[0.         0.         0.         ... 0.         0.70611817 0.        ]
#   [0.         0.         0.         ... 0.         0.36244947 0.        ]
#   [0.         0.         0.         ... 0.         0.52016246 0.        ]
#   ...
#   [0.         0.         0.         ... 0.         0.5099765  0.        ]
#   [0.         0.         0.         ... 0.         0.5016797  0.        ]
#   [0.         0.         0.         ... 0.         0.6678728  0.        ]]
#
#  [[0.         0.         0.         ... 0.         0.645437   0.        ]
#   [0.         0.         0.         ... 0.         0.39199272 0.        ]
#   [0.         0.         0.         ... 0.         0.52771604 0.        ]
#   ...
#   [0.         0.         0.         ... 0.         0.43445027 0.        ]
#   [0.         0.         0.         ... 0.         0.47818816 0.        ]
#   [0.         0.         0.         ... 0.         0.67849815 0.        ]]
#
#  ...
#
#  [[0.6033386  0.         0.         ... 0.         0.8287384  0.        ]
#   [1.05064    0.         0.         ... 0.         0.5342935  0.        ]
#   [0.8901306  0.         0.         ... 0.         0.73430216 0.        ]
#   ...
#   [0.1601505  0.         4.301766   ... 0.         0.72907645 0.        ]
#   [0.09652367 0.         3.7067218  ... 0.         0.34605843 0.        ]
#   [0.         0.         2.3435242  ... 0.         0.6833824  0.        ]]
#
#  [[0.36256275 0.         0.         ... 0.         0.792837   0.        ]
#   [0.67072815 0.         0.         ... 0.         0.34703887 0.        ]
#   [0.41887635 0.         0.         ... 0.         0.46130234 0.        ]
#   ...
#   [0.3507006  0.         3.4388463  ... 0.         0.6232669  0.        ]
#   [0.16190708 0.         2.9635737  ... 0.         0.22358727 0.        ]
#   [0.         0.         2.0439281  ... 0.         0.6448049  0.        ]]
#
#  [[0.04734452 0.         0.07083544 ... 0.         0.8971117  0.        ]
#   [0.08330967 0.         0.         ... 0.         0.82250655 0.        ]
#   [0.0468536  0.         0.         ... 0.         0.8906715  0.        ]
#   ...
#   [0.01372829 0.         1.3544066  ... 0.         0.9637737  0.        ]
#   [0.         0.         1.1242634  ... 0.         0.6825567  0.        ]
#   [0.         0.         0.74260557 ... 0.         1.0439835  0.        ]]]
# val_transfer_values.shape (1000, 14, 14, 512)

# %%
if config.ATTENTION:
    print(transfer_values.shape)
    transfer_values = transfer_values.reshape(len(train_filenames_with_all_captions), transfer_values.shape[1] ** 2, -1)
    val_transfer_values = val_transfer_values.reshape(len(val_filenames_with_all_captions), val_transfer_values.shape[1] ** 2, -1)
    print(transfer_values.shape)
# Out:
# (6000, 14, 14, 512)
# (6000, 196, 512)

# %%
decoder_model = decoder.Decoder(config.DECODER.INITIAL_STATE_SIZE, # these are declared in configs > default.py
                                config.DECODER.EMBEDDING_OUT_SIZE,
                                config.DECODER.NUM_RNN_LAYERS,
                                config.DECODER.GRU,
                                config.DECODER.BATCH_NORM,
                                config.DECODER.DROPOUT,
                                config.ATTENTION,
                                config.DECODER.ATTN_TYPE,
                                transfer_values,
                                train_vocab)
decoder_model = decoder_model.build_model()
# plot_model(decoder_model, to_file='decoder_model.png')
# print('decoder_model.summary()',decoder_model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:4139: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:3446: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
if config.DECODER.GRU:
    generator = batch_generator.generate_batch(transfer_values, 
                                               train_captions_tokens, 
                                               number_of_words=train_vocab.number_of_words, 
                                               batch_size=config.DECODER.BATCH_SIZE)
    val_generator = batch_generator.generate_batch(val_transfer_values, 
                                                   val_captions_tokens, 
                                                   number_of_words=train_vocab.number_of_words, 
                                                   batch_size=config.DECODER.BATCH_SIZE)
else:
    generator = batch_generator.generate_batch(transfer_values, 
                                               train_captions_tokens, 
                                               number_of_words=train_vocab.number_of_words, 
                                               batch_size=config.DECODER.BATCH_SIZE, 
                                               gru=config.DECODER.GRU)
    
    val_generator = batch_generator.generate_batch(val_transfer_values, 
                                                   val_captions_tokens, 
                                                   number_of_words=train_vocab.number_of_words, 
                                                   batch_size=config.DECODER.BATCH_SIZE, 
                                                   gru=config.DECODER.GRU)

# %%
if config.DECODER.OPTIMIZER:
    optimizer = RMSprop(lr=config.DECODER.LR, decay=config.DECODER.DECAY)

# %%
decoder_model.compile(optimizer=optimizer,
                      loss=config.DECODER.LOSS)
print('decoder_model.summary()',decoder_model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:3296: The name tf.log is deprecated. Please use tf.math.log instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# encoder_input (InputLayer)      (None, 196, 512)     0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 512)          0           encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 512)          262656      lambda_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 512)          2048        dense_5[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 1, 512)       0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 196, 512)     262656      encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 512)       262656      lambda_3[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_15[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_24[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_30[0][0]
#                                                                  lambda_33[0][0]
#                                                                  lambda_36[0][0]
#                                                                  lambda_39[0][0]
#                                                                  lambda_42[0][0]
#                                                                  lambda_45[0][0]
#                                                                  lambda_48[0][0]
#                                                                  lambda_51[0][0]
#                                                                  lambda_54[0][0]
#                                                                  lambda_57[0][0]
#                                                                  lambda_60[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_66[0][0]
#                                                                  lambda_69[0][0]
#                                                                  lambda_72[0][0]
#                                                                  lambda_75[0][0]
#                                                                  lambda_78[0][0]
#                                                                  lambda_81[0][0]
#                                                                  lambda_84[0][0]
#                                                                  lambda_87[0][0]
#                                                                  lambda_90[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 196, 512)     0           dense_2[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 196, 512)     0           add_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 196, 1)       513         lambda_4[0][0]
#                                                                  lambda_7[0][0]
#                                                                  lambda_10[0][0]
#                                                                  lambda_13[0][0]
#                                                                  lambda_16[0][0]
#                                                                  lambda_19[0][0]
#                                                                  lambda_22[0][0]
#                                                                  lambda_25[0][0]
#                                                                  lambda_28[0][0]
#                                                                  lambda_31[0][0]
#                                                                  lambda_34[0][0]
#                                                                  lambda_37[0][0]
#                                                                  lambda_40[0][0]
#                                                                  lambda_43[0][0]
#                                                                  lambda_46[0][0]
#                                                                  lambda_49[0][0]
#                                                                  lambda_52[0][0]
#                                                                  lambda_55[0][0]
#                                                                  lambda_58[0][0]
#                                                                  lambda_61[0][0]
#                                                                  lambda_64[0][0]
#                                                                  lambda_67[0][0]
#                                                                  lambda_70[0][0]
#                                                                  lambda_73[0][0]
#                                                                  lambda_76[0][0]
#                                                                  lambda_79[0][0]
#                                                                  lambda_82[0][0]
#                                                                  lambda_85[0][0]
#                                                                  lambda_88[0][0]
#                                                                  lambda_91[0][0]
# __________________________________________________________________________________________________
# weights_0 (Lambda)              (None, 196, 1)       0           dense_4[0][0]
# __________________________________________________________________________________________________
# decoder_input (InputLayer)      (None, 30)           0
# __________________________________________________________________________________________________
# dot_1 (Dot)                     (None, 1, 512)       0           weights_0[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 512)       262656      lambda_3[0][0]
#                                                                  lambda_6[0][0]
#                                                                  lambda_9[0][0]
#                                                                  lambda_12[0][0]
#                                                                  lambda_15[0][0]
#                                                                  lambda_18[0][0]
#                                                                  lambda_21[0][0]
#                                                                  lambda_24[0][0]
#                                                                  lambda_27[0][0]
#                                                                  lambda_30[0][0]
#                                                                  lambda_33[0][0]
#                                                                  lambda_36[0][0]
#                                                                  lambda_39[0][0]
#                                                                  lambda_42[0][0]
#                                                                  lambda_45[0][0]
#                                                                  lambda_48[0][0]
#                                                                  lambda_51[0][0]
#                                                                  lambda_54[0][0]
#                                                                  lambda_57[0][0]
#                                                                  lambda_60[0][0]
#                                                                  lambda_63[0][0]
#                                                                  lambda_66[0][0]
#                                                                  lambda_69[0][0]
#                                                                  lambda_72[0][0]
#                                                                  lambda_75[0][0]
#                                                                  lambda_78[0][0]
#                                                                  lambda_81[0][0]
#                                                                  lambda_84[0][0]
#                                                                  lambda_87[0][0]
#                                                                  lambda_90[0][0]
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 30, 512)      3774976     decoder_input[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 512)          0           encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 1, 512)       0           dot_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 512)          262656      lambda_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 1, 1024)      0           multiply_1[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 512)          2048        dense_6[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 512), (None, 3147776     concatenate_1[0][0]
#                                                                  batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  lstm_1[0][0]
#                                                                  lstm_1[0][2]
#                                                                  concatenate_3[0][0]
#                                                                  lstm_1[1][0]
#                                                                  lstm_1[1][2]
#                                                                  concatenate_4[0][0]
#                                                                  lstm_1[2][0]
#                                                                  lstm_1[2][2]
#                                                                  concatenate_5[0][0]
#                                                                  lstm_1[3][0]
#                                                                  lstm_1[3][2]
#                                                                  concatenate_6[0][0]
#                                                                  lstm_1[4][0]
#                                                                  lstm_1[4][2]
#                                                                  concatenate_7[0][0]
#                                                                  lstm_1[5][0]
#                                                                  lstm_1[5][2]
#                                                                  concatenate_8[0][0]
#                                                                  lstm_1[6][0]
#                                                                  lstm_1[6][2]
#                                                                  concatenate_9[0][0]
#                                                                  lstm_1[7][0]
#                                                                  lstm_1[7][2]
#                                                                  concatenate_10[0][0]
#                                                                  lstm_1[8][0]
#                                                                  lstm_1[8][2]
#                                                                  concatenate_11[0][0]
#                                                                  lstm_1[9][0]
#                                                                  lstm_1[9][2]
#                                                                  concatenate_12[0][0]
#                                                                  lstm_1[10][0]
#                                                                  lstm_1[10][2]
#                                                                  concatenate_13[0][0]
#                                                                  lstm_1[11][0]
#                                                                  lstm_1[11][2]
#                                                                  concatenate_14[0][0]
#                                                                  lstm_1[12][0]
#                                                                  lstm_1[12][2]
#                                                                  concatenate_15[0][0]
#                                                                  lstm_1[13][0]
#                                                                  lstm_1[13][2]
#                                                                  concatenate_16[0][0]
#                                                                  lstm_1[14][0]
#                                                                  lstm_1[14][2]
#                                                                  concatenate_17[0][0]
#                                                                  lstm_1[15][0]
#                                                                  lstm_1[15][2]
#                                                                  concatenate_18[0][0]
#                                                                  lstm_1[16][0]
#                                                                  lstm_1[16][2]
#                                                                  concatenate_19[0][0]
#                                                                  lstm_1[17][0]
#                                                                  lstm_1[17][2]
#                                                                  concatenate_20[0][0]
#                                                                  lstm_1[18][0]
#                                                                  lstm_1[18][2]
#                                                                  concatenate_21[0][0]
#                                                                  lstm_1[19][0]
#                                                                  lstm_1[19][2]
#                                                                  concatenate_22[0][0]
#                                                                  lstm_1[20][0]
#                                                                  lstm_1[20][2]
#                                                                  concatenate_23[0][0]
#                                                                  lstm_1[21][0]
#                                                                  lstm_1[21][2]
#                                                                  concatenate_24[0][0]
#                                                                  lstm_1[22][0]
#                                                                  lstm_1[22][2]
#                                                                  concatenate_25[0][0]
#                                                                  lstm_1[23][0]
#                                                                  lstm_1[23][2]
#                                                                  concatenate_26[0][0]
#                                                                  lstm_1[24][0]
#                                                                  lstm_1[24][2]
#                                                                  concatenate_27[0][0]
#                                                                  lstm_1[25][0]
#                                                                  lstm_1[25][2]
#                                                                  concatenate_28[0][0]
#                                                                  lstm_1[26][0]
#                                                                  lstm_1[26][2]
#                                                                  concatenate_29[0][0]
#                                                                  lstm_1[27][0]
#                                                                  lstm_1[27][2]
#                                                                  concatenate_30[0][0]
#                                                                  lstm_1[28][0]
#                                                                  lstm_1[28][2]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 1, 512)       0           lstm_1[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 196, 512)     0           dense_2[1][0]
#                                                                  dense_1[1][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 196, 512)     0           add_2[0][0]
# __________________________________________________________________________________________________
# weights_1 (Lambda)              (None, 196, 1)       0           dense_4[1][0]
# __________________________________________________________________________________________________
# dot_2 (Dot)                     (None, 1, 512)       0           weights_1[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 1, 512)       0           dot_2[0][0]
#                                                                  dense_3[1][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 1024)      0           multiply_2[0][0]
#                                                                  lambda_8[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 1, 512)       0           lstm_1[1][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 196, 512)     0           dense_2[2][0]
#                                                                  dense_1[2][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 196, 512)     0           add_3[0][0]
# __________________________________________________________________________________________________
# weights_2 (Lambda)              (None, 196, 1)       0           dense_4[2][0]
# __________________________________________________________________________________________________
# dot_3 (Dot)                     (None, 1, 512)       0           weights_2[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1, 512)       0           dot_3[0][0]
#                                                                  dense_3[2][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 1024)      0           multiply_3[0][0]
#                                                                  lambda_11[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 1, 512)       0           lstm_1[2][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 196, 512)     0           dense_2[3][0]
#                                                                  dense_1[3][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 196, 512)     0           add_4[0][0]
# __________________________________________________________________________________________________
# weights_3 (Lambda)              (None, 196, 1)       0           dense_4[3][0]
# __________________________________________________________________________________________________
# dot_4 (Dot)                     (None, 1, 512)       0           weights_3[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 1, 512)       0           dot_4[0][0]
#                                                                  dense_3[3][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1, 1024)      0           multiply_4[0][0]
#                                                                  lambda_14[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 1, 512)       0           lstm_1[3][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 196, 512)     0           dense_2[4][0]
#                                                                  dense_1[4][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 196, 512)     0           add_5[0][0]
# __________________________________________________________________________________________________
# weights_4 (Lambda)              (None, 196, 1)       0           dense_4[4][0]
# __________________________________________________________________________________________________
# dot_5 (Dot)                     (None, 1, 512)       0           weights_4[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 1, 512)       0           dot_5[0][0]
#                                                                  dense_3[4][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 1, 1024)      0           multiply_5[0][0]
#                                                                  lambda_17[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 1, 512)       0           lstm_1[4][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 196, 512)     0           dense_2[5][0]
#                                                                  dense_1[5][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 196, 512)     0           add_6[0][0]
# __________________________________________________________________________________________________
# weights_5 (Lambda)              (None, 196, 1)       0           dense_4[5][0]
# __________________________________________________________________________________________________
# dot_6 (Dot)                     (None, 1, 512)       0           weights_5[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 1, 512)       0           dot_6[0][0]
#                                                                  dense_3[5][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 1, 1024)      0           multiply_6[0][0]
#                                                                  lambda_20[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 1, 512)       0           lstm_1[5][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 196, 512)     0           dense_2[6][0]
#                                                                  dense_1[6][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 196, 512)     0           add_7[0][0]
# __________________________________________________________________________________________________
# weights_6 (Lambda)              (None, 196, 1)       0           dense_4[6][0]
# __________________________________________________________________________________________________
# dot_7 (Dot)                     (None, 1, 512)       0           weights_6[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 1, 512)       0           dot_7[0][0]
#                                                                  dense_3[6][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 1, 1024)      0           multiply_7[0][0]
#                                                                  lambda_23[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 1, 512)       0           lstm_1[6][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 196, 512)     0           dense_2[7][0]
#                                                                  dense_1[7][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 196, 512)     0           add_8[0][0]
# __________________________________________________________________________________________________
# weights_7 (Lambda)              (None, 196, 1)       0           dense_4[7][0]
# __________________________________________________________________________________________________
# dot_8 (Dot)                     (None, 1, 512)       0           weights_7[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 1, 512)       0           dot_8[0][0]
#                                                                  dense_3[7][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 1, 1024)      0           multiply_8[0][0]
#                                                                  lambda_26[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 1, 512)       0           lstm_1[7][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 196, 512)     0           dense_2[8][0]
#                                                                  dense_1[8][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 196, 512)     0           add_9[0][0]
# __________________________________________________________________________________________________
# weights_8 (Lambda)              (None, 196, 1)       0           dense_4[8][0]
# __________________________________________________________________________________________________
# dot_9 (Dot)                     (None, 1, 512)       0           weights_8[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 1, 512)       0           dot_9[0][0]
#                                                                  dense_3[8][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 1, 1024)      0           multiply_9[0][0]
#                                                                  lambda_29[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 1, 512)       0           lstm_1[8][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 196, 512)     0           dense_2[9][0]
#                                                                  dense_1[9][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 196, 512)     0           add_10[0][0]
# __________________________________________________________________________________________________
# weights_9 (Lambda)              (None, 196, 1)       0           dense_4[9][0]
# __________________________________________________________________________________________________
# dot_10 (Dot)                    (None, 1, 512)       0           weights_9[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 1, 512)       0           dot_10[0][0]
#                                                                  dense_3[9][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 1, 1024)      0           multiply_10[0][0]
#                                                                  lambda_32[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 1, 512)       0           lstm_1[9][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 196, 512)     0           dense_2[10][0]
#                                                                  dense_1[10][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 196, 512)     0           add_11[0][0]
# __________________________________________________________________________________________________
# weights_10 (Lambda)             (None, 196, 1)       0           dense_4[10][0]
# __________________________________________________________________________________________________
# dot_11 (Dot)                    (None, 1, 512)       0           weights_10[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 1, 512)       0           dot_11[0][0]
#                                                                  dense_3[10][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 1, 1024)      0           multiply_11[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 1, 512)       0           lstm_1[10][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 196, 512)     0           dense_2[11][0]
#                                                                  dense_1[11][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 196, 512)     0           add_12[0][0]
# __________________________________________________________________________________________________
# weights_11 (Lambda)             (None, 196, 1)       0           dense_4[11][0]
# __________________________________________________________________________________________________
# dot_12 (Dot)                    (None, 1, 512)       0           weights_11[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 1, 512)       0           dot_12[0][0]
#                                                                  dense_3[11][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 1, 1024)      0           multiply_12[0][0]
#                                                                  lambda_38[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 1, 512)       0           lstm_1[11][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 196, 512)     0           dense_2[12][0]
#                                                                  dense_1[12][0]
# ...
#                                                                  lambda_74[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 1, 512)       0           lstm_1[23][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 196, 512)     0           dense_2[24][0]
#                                                                  dense_1[24][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 196, 512)     0           add_25[0][0]
# __________________________________________________________________________________________________
# weights_24 (Lambda)             (None, 196, 1)       0           dense_4[24][0]
# __________________________________________________________________________________________________
# dot_25 (Dot)                    (None, 1, 512)       0           weights_24[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 1, 512)       0           dot_25[0][0]
#                                                                  dense_3[24][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 1, 1024)      0           multiply_25[0][0]
#                                                                  lambda_77[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 1, 512)       0           lstm_1[24][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 196, 512)     0           dense_2[25][0]
#                                                                  dense_1[25][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 196, 512)     0           add_26[0][0]
# __________________________________________________________________________________________________
# weights_25 (Lambda)             (None, 196, 1)       0           dense_4[25][0]
# __________________________________________________________________________________________________
# dot_26 (Dot)                    (None, 1, 512)       0           weights_25[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 1, 512)       0           dot_26[0][0]
#                                                                  dense_3[25][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 1, 1024)      0           multiply_26[0][0]
#                                                                  lambda_80[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 1, 512)       0           lstm_1[25][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 196, 512)     0           dense_2[26][0]
#                                                                  dense_1[26][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 196, 512)     0           add_27[0][0]
# __________________________________________________________________________________________________
# weights_26 (Lambda)             (None, 196, 1)       0           dense_4[26][0]
# __________________________________________________________________________________________________
# dot_27 (Dot)                    (None, 1, 512)       0           weights_26[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 1, 512)       0           dot_27[0][0]
#                                                                  dense_3[26][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 1, 1024)      0           multiply_27[0][0]
#                                                                  lambda_83[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 1, 512)       0           lstm_1[26][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 196, 512)     0           dense_2[27][0]
#                                                                  dense_1[27][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 196, 512)     0           add_28[0][0]
# __________________________________________________________________________________________________
# weights_27 (Lambda)             (None, 196, 1)       0           dense_4[27][0]
# __________________________________________________________________________________________________
# dot_28 (Dot)                    (None, 1, 512)       0           weights_27[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 1, 512)       0           dot_28[0][0]
#                                                                  dense_3[27][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 1, 1024)      0           multiply_28[0][0]
#                                                                  lambda_86[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 1, 512)       0           lstm_1[27][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 196, 512)     0           dense_2[28][0]
#                                                                  dense_1[28][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 196, 512)     0           add_29[0][0]
# __________________________________________________________________________________________________
# weights_28 (Lambda)             (None, 196, 1)       0           dense_4[28][0]
# __________________________________________________________________________________________________
# dot_29 (Dot)                    (None, 1, 512)       0           weights_28[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 1, 512)       0           dot_29[0][0]
#                                                                  dense_3[28][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 1, 1024)      0           multiply_29[0][0]
#                                                                  lambda_89[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 1, 512)       0           lstm_1[28][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 196, 512)     0           dense_2[29][0]
#                                                                  dense_1[29][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 196, 512)     0           add_30[0][0]
# __________________________________________________________________________________________________
# weights_29 (Lambda)             (None, 196, 1)       0           dense_4[29][0]
# __________________________________________________________________________________________________
# dot_30 (Dot)                    (None, 1, 512)       0           weights_29[0][0]
#                                                                  encoder_input[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 1, 512)       0           dot_30[0][0]
#                                                                  dense_3[29][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 1, 512)       0           embedding[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 1, 1024)      0           multiply_30[0][0]
#                                                                  lambda_92[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 30, 512)      0           lstm_1[0][0]
#                                                                  lstm_1[1][0]
#                                                                  lstm_1[2][0]
#                                                                  lstm_1[3][0]
#                                                                  lstm_1[4][0]
#                                                                  lstm_1[5][0]
#                                                                  lstm_1[6][0]
#                                                                  lstm_1[7][0]
#                                                                  lstm_1[8][0]
#                                                                  lstm_1[9][0]
#                                                                  lstm_1[10][0]
#                                                                  lstm_1[11][0]
#                                                                  lstm_1[12][0]
#                                                                  lstm_1[13][0]
#                                                                  lstm_1[14][0]
#                                                                  lstm_1[15][0]
#                                                                  lstm_1[16][0]
#                                                                  lstm_1[17][0]
#                                                                  lstm_1[18][0]
#                                                                  lstm_1[19][0]
#                                                                  lstm_1[20][0]
#                                                                  lstm_1[21][0]
#                                                                  lstm_1[22][0]
#                                                                  lstm_1[23][0]
#                                                                  lstm_1[24][0]
#                                                                  lstm_1[25][0]
#                                                                  lstm_1[26][0]
#                                                                  lstm_1[27][0]
#                                                                  lstm_1[28][0]
#                                                                  lstm_1[29][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   (None, 30, 512)      2099200     lambda_93[0][0]
#                                                                  batch_normalization_1[0][0]
#                                                                  batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# decoder_output (Dense)          (None, 30, 7373)     3782349     lstm_2[0][0]
# ==================================================================================================
# Total params: 14,122,190
# Trainable params: 14,120,142
# Non-trainable params: 2,048
# __________________________________________________________________________________________________
# decoder_model.summary() None

# %%
model_json = decoder_model.to_json()
try:
    os.mkdir(config.PATH.MODELS_ARCHITECTURE_PATH)
except:
    print('The folder already exists')
with open(model_path, "w") as json_file:
    json.dump(json.loads(model_json), json_file, indent=4)
# Out:
# The folder already exists
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'batch_normalization_1/cond/Merge:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'batch_normalization_2/cond/Merge:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_1/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_1/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_2/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_2/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_3/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_3/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_4/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_4/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_5/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_5/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_6/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_6/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_7/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_7/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_8/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_8/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_9/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_9/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_10/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_10/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_11/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_11/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_12/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_12/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_13/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_13/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_14/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_14/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_15/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_15/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_16/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_16/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_17/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_17/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_18/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_18/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_19/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_19/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_20/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_20/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_21/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_21/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_22/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_22/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_23/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_23/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_24/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_24/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_25/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_25/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_26/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_26/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_27/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_27/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_1 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1_28/TensorArrayReadV3:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'lstm_1_28/while/Exit_4:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '
# C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\engine\network.py:877: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'batch_normalization_1/cond/Merge:0' shape=(?, 512) dtype=float32>, <tf.Tensor 'batch_normalization_2/cond/Merge:0' shape=(?, 512) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %% [markdown]
# ### Checkpoints
#
# During the training process, it is a good idea to save the weights periodically.

# %%
try:
    os.mkdir(configs.WEIGHTS_PATH)
except:
    print('The folder already exists')

checkpoints = ModelCheckpoint(path_checkpoint, 
                              verbose=config.DECODER.VERBOSE, 
                              save_weights_only=True, 
                              save_best_only=config.DECODER.SAVE_BEST)

reduce_lr = ReduceLROnPlateau(monitor=config.DECODER.MONITOR, 
                              factor=config.DECODER.FACTOR,
                              patience=config.DECODER.PATIENCE, 
                              verbose=config.DECODER.VERBOSE, 
                              min_lr=config.DECODER.MIN_LR)
# Out:
# The folder already exists

# %%
tf_configuration = tf.ConfigProto()
tf_configuration.gpu_options.allow_growth = True
set_session(tf.Session(config=tf_configuration))
start = time.time()
callbacks = decoder_model.fit_generator(generator=generator,
                                        steps_per_epoch=int(len(train_filenames_with_all_captions) / config.DECODER.BATCH_SIZE),
                                        epochs=config.DECODER.EPOCHS,
                                        callbacks=[checkpoints, reduce_lr],
                                        validation_data=val_generator,
                                        validation_steps=config.DECODER.VAL_STEPS)
time_train = time.time() - start
# Out:
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\tensorflow_core\python\ops\math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:987: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Epoch 1/20
# transfer_values1.shape (1000, 196, 512)
# len(captions_tokens) transfer_values1.shape (6000, 196, 512)
# len(captions_tokens) 6000
# len(captions_tokens[0]) 5
# 1000
# len(captions_tokens[0]) 5
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From C:\Users\MStopa\AppData\Local\Continuum\anaconda3\envs\PythonGPU\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# 187/187 [==============================] - 725s 4s/step - loss: 2.1574 - val_loss: 1.8545
#
# Epoch 00001: val_loss improved from inf to 1.85448, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 2/20
# 187/187 [==============================] - 695s 4s/step - loss: 1.5833 - val_loss: 1.5938
#
# Epoch 00002: val_loss improved from 1.85448 to 1.59383, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 3/20
# 187/187 [==============================] - 728s 4s/step - loss: 1.4633 - val_loss: 1.4371
#
# Epoch 00003: val_loss improved from 1.59383 to 1.43705, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 4/20
# 187/187 [==============================] - 717s 4s/step - loss: 1.3724 - val_loss: 1.4036
#
# Epoch 00004: val_loss improved from 1.43705 to 1.40360, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 5/20
# 187/187 [==============================] - 682s 4s/step - loss: 1.3402 - val_loss: 1.4604
#
# Epoch 00005: val_loss did not improve from 1.40360
# Epoch 6/20
# 187/187 [==============================] - 691s 4s/step - loss: 1.2877 - val_loss: 1.3827
#
# Epoch 00006: val_loss improved from 1.40360 to 1.38270, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 7/20
# 187/187 [==============================] - 719s 4s/step - loss: 1.2567 - val_loss: 1.4731
#
# Epoch 00007: val_loss did not improve from 1.38270
# Epoch 8/20
# 187/187 [==============================] - 701s 4s/step - loss: 1.2187 - val_loss: 1.4100
#
# Epoch 00008: val_loss did not improve from 1.38270
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 9/20
# 187/187 [==============================] - 685s 4s/step - loss: 1.1761 - val_loss: 1.3443
#
# Epoch 00009: val_loss improved from 1.38270 to 1.34432, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 10/20
# 187/187 [==============================] - 666s 4s/step - loss: 1.1727 - val_loss: 1.3754
#
# Epoch 00010: val_loss did not improve from 1.34432
# Epoch 11/20
# 187/187 [==============================] - 679s 4s/step - loss: 1.1525 - val_loss: 1.4305
#
# Epoch 00011: val_loss did not improve from 1.34432
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 12/20
# 187/187 [==============================] - 678s 4s/step - loss: 1.1243 - val_loss: 1.3330
#
# Epoch 00012: val_loss improved from 1.34432 to 1.33302, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5
# Epoch 13/20
# 187/187 [==============================] - 689s 4s/step - loss: 1.1221 - val_loss: 1.4010
#
# Epoch 00013: val_loss did not improve from 1.33302
# Epoch 14/20
# 187/187 [==============================] - 685s 4s/step - loss: 1.1029 - val_loss: 1.3419
#
# Epoch 00014: val_loss did not improve from 1.33302
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 15/20
# 187/187 [==============================] - 702s 4s/step - loss: 1.0959 - val_loss: 1.5063
#
# Epoch 00015: val_loss did not improve from 1.33302
# Epoch 16/20
# 187/187 [==============================] - 683s 4s/step - loss: 1.0860 - val_loss: 1.4539
#
# Epoch 00016: val_loss did not improve from 1.33302
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 17/20
# 187/187 [==============================] - 715s 4s/step - loss: 1.0736 - val_loss: 1.3866
#
# Epoch 00017: val_loss did not improve from 1.33302
# Epoch 18/20
# 187/187 [==============================] - 741s 4s/step - loss: 1.0715 - val_loss: 1.3657
#
# Epoch 00018: val_loss did not improve from 1.33302
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 19/20
# 187/187 [==============================] - 700s 4s/step - loss: 1.0816 - val_loss: 1.3796
#
# Epoch 00019: val_loss did not improve from 1.33302
# Epoch 20/20
# 187/187 [==============================] - 722s 4s/step - loss: 1.0629 - val_loss: 1.3287
#
# Epoch 00020: val_loss improved from 1.33302 to 1.32872, saving model to ./model_files/weights/VGG16_LSTM_Flickr8k_2l_32b_attn_bahdanau.hdf5

# %%
print("Time for training: {} seconds".format(time_train))
# Out:
# Time for training: 14048.330514669418 seconds

# %%
if not os.path.exists(config.PATH.CALLBACKS_PATH):
    os.mkdir(config.PATH.CALLBACKS_PATH)   
callback_df = pd.DataFrame(callbacks.history)
callback_df.to_csv(callbacks_path, index=None)
